# %%
import requests
from bs4 import BeautifulSoup
import json
from datetime import datetime
import UCSD_pdf_dates
import os
import PyPDF2
# Base URL for the UCSD newspaper archives
base_url = "https://library.ucsd.edu/dc/"

# Load the subpage links from the subpage_links.json file
with open("subpage_links.json", "r") as f:
    subpage_links = json.load(f)

# List to store all the PDF links
pdf_links = []
# Loop through all the subpages and scrape the PDF links
for subpage_link in subpage_links:
    # Make a GET request to the subpage URL
    response = requests.get(subpage_link)

    # Create a BeautifulSoup object from the response HTML
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all the PDF links on the page
    pdf_links_on_page = soup.find_all('a', class_='dams-search-thumbnail-link') #pdf_links_on_page = soup.find_all('li', class_='dams-sr') 

    # Loop through all the PDF links and extract the PDF URL
    for pdf_link_on_page in pdf_links_on_page:
        try:
            # Extract the relative URL for the PDF
            pdf_url = pdf_link_on_page['href']

            pdf_url = pdf_url.replace("/dc/", "")

            # Construct the absolute URL for the PDF file and add the "_1.pdf" suffix
            pdf_full_url = f"{base_url}{pdf_url.split('?')[0]}/_1.pdf"
            
            # Construct the absolute URL for the PDF file and add the "_1.pdf" suffix
            date_url = f"{base_url}{pdf_url.split('?')[0]}"
            print(date_url)
            date_response = requests.get(date_url)
            date_soup = BeautifulSoup(date_response.content, 'html.parser')

            # Find the date element
            date_elem = date_soup.find('dt', string='Creation Date').find_next_sibling('dd').find('ul', class_='unstyled').find('li').get_text(strip=True)
            if date_elem:
                date = date_elem
            else:
                date = None

            # Check if the date element exists and formats the dates (YYYY_mm_dd)
            if date_elem is not None:
                date_obj = datetime.strptime(date_elem, '%B %d, %Y')
                formatted_date = date_obj.strftime('%Y_%m_%d')
                print(formatted_date)
            else:
                raise ValueError("Could not find date element")

        except (KeyError, ValueError, AttributeError) as e:
            # Handle any exceptions that occur
            print(f"Error: {e}")
            continue
            

            # Create a dictionary with the PDF URL and date
        pdf_info = {
            'date': formatted_date,
            'pdf_url': pdf_full_url
        }


            # Append the dictionary to the list of PDF links
        pdf_links.append(pdf_info)
        #print(f"PDF link found: {pdf_full_url}")
            # Skip links that do not have a href attribute or have invalid HTML
    continue

# Write the PDF links to a JSON file
if len(pdf_links) > 0:
    with open('UCSD_article_pages.json', 'w') as f:
        json.dump(pdf_links, f, indent=4)
else:
    print("No PDF links found.")

import io
# Load the JSON file
with open("UCSD_article_pages.json", "r") as f:
    pdf_information = json.load(f)

# Create the output directory if it doesn't exist
if not os.path.exists("journal_data/txt"):
    os.makedirs("journal_data/txt")

# Open the output file
output_file = open("journal_data/txt/UCSD/all_text.txt", "a", encoding="utf-8")

# Loop through each PDF link and extract the text
for info in pdf_information:
    pdf_full_url = info['pdf_url']
    date = info['date']
    print(date)
    try:
        # Make a GET request to the PDF URL
        response = requests.get(pdf_full_url)

        # Create a PDF object from the response content
        pdf = PyPDF2.PdfReader(io.BytesIO(response.content))

        # Extract the text from the PDF object
        text = ""
        for i in range(len(pdf.pages)):
            text += pdf.pages[i].extract_text()
            # Write the text to a file with the publication date in the filename
            if date is not None:
             # Extract year, month, and day from the date string

                filename = f"journal_data/txt/UCSD/{date}.txt"
                print(filename)
            else:
                filename = f"journal_data/txt/UCSD/unknown_date.txt"

            # Create the directory structure for the output file if it doesn't exist   
            os.makedirs(os.path.dirname(filename), exist_ok=True)
            with open(filename, "w", encoding="utf-8") as f:
                f.write(text)
                output_file.write(text)
    except Exception as e:
        print(f"Error: {e}")
        continue
output_file.close()
# Out:
# https://library.ucsd.edu/dc/object/bb75533932
# 2023_01_30
# https://library.ucsd.edu/dc/object/bb8201865f
# 2023_01_23
# https://library.ucsd.edu/dc/object/bb8884462f
# 2023_01_17
# https://library.ucsd.edu/dc/object/bb9567064f
# 2023_01_09
# https://library.ucsd.edu/dc/object/bb02154457
# 2022_12_23
# https://library.ucsd.edu/dc/object/bb08980448
# 2022_12_04
# https://library.ucsd.edu/dc/object/bb1580644j
# 2022_11_29
# https://library.ucsd.edu/dc/object/bb22291132
# 2022_11_28
# https://library.ucsd.edu/dc/object/bb29117140
# 2022_11_21
# https://library.ucsd.edu/dc/object/bb3594311v
# 2022_11_14
# https://library.ucsd.edu/dc/object/bb4242783m
# 2022_11_07
# https://library.ucsd.edu/dc/object/bb49253868
# 2022_10_31
# https://library.ucsd.edu/dc/object/bb6256451f
# 2022_10_17
# https://library.ucsd.edu/dc/object/bb69390564
# 2022_10_10
# https://library.ucsd.edu/dc/object/bb7621655w
# 2022_10_03
# https://library.ucsd.edu/dc/object/bb82701222
# 2022_09_26
# https://library.ucsd.edu/dc/object/bb89527248
# 2022_08_11
# https://library.ucsd.edu/dc/object/bb9635323q
# 2022_08_04
# https://library.ucsd.edu/dc/object/bb0283703f
# 2022_07_18
# https://library.ucsd.edu/dc/object/bb09663042
# 2022_06_20
# https://library.ucsd.edu/dc/object/bb3968542m
# 2022_05_31
# https://library.ucsd.edu/dc/object/bb4651143b
# 2022_05_23
# https://library.ucsd.edu/dc/object/bb5299611v
# 2022_05_16
# https://library.ucsd.edu/dc/object/bb5982212q
# 2022_05_09
# https://library.ucsd.edu/dc/object/bb66648117
# 2022_05_02
# https://library.ucsd.edu/dc/object/bb7995881h
# 2022_04_18
# https://library.ucsd.edu/dc/object/bb8678481g
# 2022_04_11
# https://library.ucsd.edu/dc/object/bb9361081p
# 2022_04_04
# https://library.ucsd.edu/dc/object/bb73474116
# 2022_04_25
# https://library.ucsd.edu/dc/object/bb00094627
# 2022_03_28
# https://library.ucsd.edu/dc/object/bb06920642
# 2022_03_07
# https://library.ucsd.edu/dc/object/bb13746622
# 2022_02_28
# https://library.ucsd.edu/dc/object/bb20231309
# 2022_02_22
# https://library.ucsd.edu/dc/object/bb2705730g
# 2022_02_14
# https://library.ucsd.edu/dc/object/bb33883292
# 2022_02_07
# https://library.ucsd.edu/dc/object/bb4036801r
# 2022_01_31
# https://library.ucsd.edu/dc/object/bb4719401v
# 2022_01_24
# https://library.ucsd.edu/dc/object/bb54019995
# 2022_01_18
# https://library.ucsd.edu/dc/object/bb6050470q
# 2022_01_10
# https://library.ucsd.edu/dc/object/bb6733072v
# 2022_01_03
# https://library.ucsd.edu/dc/object/bb3729264g
# 2021_11_29
# https://library.ucsd.edu/dc/object/bb43777348
# 2021_11_22
# https://library.ucsd.edu/dc/object/bb5060334g
# 2021_11_15
# https://library.ucsd.edu/dc/object/bb5742938q
# 2021_11_08
# https://library.ucsd.edu/dc/object/bb6391406d
# 2021_11_01
# https://library.ucsd.edu/dc/object/bb7074003t
# 2021_10_25
# https://library.ucsd.edu/dc/object/bb7756606j
# 2021_10_18
# https://library.ucsd.edu/dc/object/bb8405077q
# 2021_10_11
# https://library.ucsd.edu/dc/object/bb9087676p
# 2021_10_04
# https://library.ucsd.edu/dc/object/bb9770275h
# 2021_09_27
# https://library.ucsd.edu/dc/object/bb0418655j
# 2021_07_22
# https://library.ucsd.edu/dc/object/bb11012568
# 2021_06_27
# https://library.ucsd.edu/dc/object/bb1783856w
# 2021_06_20
# https://library.ucsd.edu/dc/object/bb24323244
# 2021_06_13
# https://library.ucsd.edu/dc/object/bb31149245
# 2021_06_06
# https://library.ucsd.edu/dc/object/bb3797526r
# 2021_05_30
# https://library.ucsd.edu/dc/object/bb44459970
# 2021_05_23
# https://library.ucsd.edu/dc/object/bb5128595x
# 2021_05_16
# https://library.ucsd.edu/dc/object/bb5811194r
# 2021_05_09
# https://library.ucsd.edu/dc/object/bb64937968
# 2021_05_02
# https://library.ucsd.edu/dc/object/bb7142266j
# 2021_04_25
# https://library.ucsd.edu/dc/object/bb7824866q
# 2021_04_18
# https://library.ucsd.edu/dc/object/bb85074655
# 2021_04_11
# https://library.ucsd.edu/dc/object/bb9155934f
# 2021_04_04
# https://library.ucsd.edu/dc/object/bb98385331
# 2021_03_28
# https://library.ucsd.edu/dc/object/bb0521042n
# 2021_03_14
# https://library.ucsd.edu/dc/object/bb11695147
# 2021_03_07
# https://library.ucsd.edu/dc/object/bb18521153
# 2021_02_28
# https://library.ucsd.edu/dc/object/bb2534712k
# 2021_02_21
# https://library.ucsd.edu/dc/object/bb31831836
# 2021_02_14
# https://library.ucsd.edu/dc/object/bb3865783c
# 2021_02_07
# https://library.ucsd.edu/dc/object/bb4548386w
# 2021_01_31
# https://library.ucsd.edu/dc/object/bb5196854n
# 2021_01_24
# https://library.ucsd.edu/dc/object/bb58794537
# 2021_01_17
# https://library.ucsd.edu/dc/object/bb6562054z
# 2021_01_10
# https://library.ucsd.edu/dc/object/bb72105249
# 2021_01_03
# https://library.ucsd.edu/dc/object/bb5876749z
# 2020_12_20
# https://library.ucsd.edu/dc/object/bb72078203
# 2020_12_13
# https://library.ucsd.edu/dc/object/bb11326794
# 2020_12_06
# https://library.ucsd.edu/dc/object/bb24978812
# 2020_11_29
# https://library.ucsd.edu/dc/object/bb6422830n
# 2020_11_22
# https://library.ucsd.edu/dc/object/bb7753898k
# 2020_11_15
# https://library.ucsd.edu/dc/object/bb4272640t
# 2020_11_08
# https://library.ucsd.edu/dc/object/bb8197589p
# 2020_11_01
# https://library.ucsd.edu/dc/object/bb95286594
# 2020_10_25
# https://library.ucsd.edu/dc/object/bb3487648s
# 2020_10_18
# https://library.ucsd.edu/dc/object/bb7412599s
# 2020_10_11
# https://library.ucsd.edu/dc/object/bb1337458h
# 2020_10_04
# https://library.ucsd.edu/dc/object/bb2668530r
# 2020_08_23
# https://library.ucsd.edu/dc/object/bb27367872
# 2020_08_16
# https://library.ucsd.edu/dc/object/bb1473978x
# 2020_08_02
# https://library.ucsd.edu/dc/object/bb5398927q
# 2020_07_26
# https://library.ucsd.edu/dc/object/bb80269384
# 2020_07_19
# https://library.ucsd.edu/dc/object/bb9392141r
# 2020_07_12
# https://library.ucsd.edu/dc/object/bb33169984
# 2020_07_05
# https://library.ucsd.edu/dc/object/bb2668240w
# 2020_06_28
# https://library.ucsd.edu/dc/object/bb33508405
# 2020_06_21
# https://library.ucsd.edu/dc/object/bb40334404
# 2020_06_14
# https://library.ucsd.edu/dc/object/bb46819097
# 2020_06_07
# https://library.ucsd.edu/dc/object/bb53645096
# 2020_05_31
# https://library.ucsd.edu/dc/object/bb60471095
# 2020_05_24
# https://library.ucsd.edu/dc/object/bb6695579g
# 2020_05_17
# https://library.ucsd.edu/dc/object/bb73781808
# 2020_05_10
# https://library.ucsd.edu/dc/object/bb8060779q
# 2020_05_03
# https://library.ucsd.edu/dc/object/bb8709249w
# 2020_04_26
# https://library.ucsd.edu/dc/object/bb9391851z
# 2020_04_19
# https://library.ucsd.edu/dc/object/bb0074360b
# 2020_04_12
# https://library.ucsd.edu/dc/object/bb0722828g
# 2020_04_05
# https://library.ucsd.edu/dc/object/bb1405428f
# 2020_03_29
# https://library.ucsd.edu/dc/object/bb20880306
# 2020_03_22
# https://library.ucsd.edu/dc/object/bb27364997
# 2020_03_15
# https://library.ucsd.edu/dc/object/bb3213338z
# 2020_03_09
# https://library.ucsd.edu/dc/object/bb38959393
# 2020_03_02
# https://library.ucsd.edu/dc/object/bb45785392
# 2020_02_24
# https://library.ucsd.edu/dc/object/bb9117828w
# 2020_02_18
# https://library.ucsd.edu/dc/object/bb10631484
# 2020_02_10
# https://library.ucsd.edu/dc/object/bb1745747s
# 2020_02_03
# https://library.ucsd.edu/dc/object/bb1472709r
# 2020_01_27
# https://library.ucsd.edu/dc/object/bb4715057x
# 2020_01_21
# https://library.ucsd.edu/dc/object/bb4442019w
# 2020_01_13
# https://library.ucsd.edu/dc/object/bb63874291
# 2020_01_06
# https://library.ucsd.edu/dc/object/bb6114386b
# 2019_12_02
# https://library.ucsd.edu/dc/object/bb67969880
# 2019_11_25
# https://library.ucsd.edu/dc/object/bb74454588
# 2019_11_18
# https://library.ucsd.edu/dc/object/bb9424997c
# Error: time data 'November, 12, 2019' does not match format '%B %d, %Y'
# https://library.ucsd.edu/dc/object/bb39641975
# Error: time data 'November, 4, 2019' does not match format '%B %d, %Y'
# https://library.ucsd.edu/dc/object/bb4646798q
# 2019_10_28
# https://library.ucsd.edu/dc/object/bb4339628q
# 2019_10_21
# https://library.ucsd.edu/dc/object/bb92202171
# 2019_10_14
# https://library.ucsd.edu/dc/object/bb63532965
# 2019_10_07
# https://library.ucsd.edu/dc/object/bb3486378g
# 2019_09_30
# https://library.ucsd.edu/dc/object/bb28033327
# 2019_05_28
# https://library.ucsd.edu/dc/object/bb3485932q
# 2019_05_20
# https://library.ucsd.edu/dc/object/bb41685357
# 2019_05_13
# https://library.ucsd.edu/dc/object/bb48511300
# 2019_05_06
# https://library.ucsd.edu/dc/object/bb54995993
# 2019_04_29
# https://library.ucsd.edu/dc/object/bb6182205b
# 2019_04_22
# https://library.ucsd.edu/dc/object/bb6864800x
# 2019_04_15
# https://library.ucsd.edu/dc/object/bb75132713
# 2019_04_08
# https://library.ucsd.edu/dc/object/bb81958744
# 2019_04_01
# https://library.ucsd.edu/dc/object/bb88784705
# 2019_03_11
# https://library.ucsd.edu/dc/object/bb9526940h
# 2019_03_04
# https://library.ucsd.edu/dc/object/bb0209453z
# 2019_02_25
# https://library.ucsd.edu/dc/object/bb0892051q
# 2019_02_19
# https://library.ucsd.edu/dc/object/bb1540520j
# 2019_02_11
# https://library.ucsd.edu/dc/object/bb4817003m
# 2019_02_04
# https://library.ucsd.edu/dc/object/bb1403919w
# 2019_01_28
# https://library.ucsd.edu/dc/object/bb20523890
# 2019_01_22
# https://library.ucsd.edu/dc/object/bb2734986m
# 2019_01_14
# https://library.ucsd.edu/dc/object/bb3417590z
# 2019_01_07
# https://library.ucsd.edu/dc/object/bb4066059v
# 2018_12_03
# https://library.ucsd.edu/dc/object/bb47486570
# 2018_11_26
# https://library.ucsd.edu/dc/object/bb5431261k
# 2018_11_19
# https://library.ucsd.edu/dc/object/bb6079730m
# 2018_11_13
# https://library.ucsd.edu/dc/object/bb67623273
# 2018_11_05
# https://library.ucsd.edu/dc/object/bb74449295
# 2018_10_29
# https://library.ucsd.edu/dc/object/bb81275273
# 2018_10_22
# https://library.ucsd.edu/dc/object/bb8775997d
# 2018_10_15
# https://library.ucsd.edu/dc/object/bb9458597c
# 2018_10_08
# https://library.ucsd.edu/dc/object/bb01411074
# 2018_10_01
# https://library.ucsd.edu/dc/object/bb0789576p
# 2018_06_04
# https://library.ucsd.edu/dc/object/bb1472177d
# 2018_05_29
# https://library.ucsd.edu/dc/object/bb2154779g
# 2018_05_21
# https://library.ucsd.edu/dc/object/bb2803246b
# 2018_05_14
# https://library.ucsd.edu/dc/object/bb3485847b
# 2018_05_07
# https://library.ucsd.edu/dc/object/bb4168449b
# 2018_04_30
# https://library.ucsd.edu/dc/object/bb4816917s
# 2018_04_23
# https://library.ucsd.edu/dc/object/bb54995155
# 2018_04_16
# https://library.ucsd.edu/dc/object/bb61821208
# 2018_04_09
# https://library.ucsd.edu/dc/object/bb68305904
# 2018_04_02
# https://library.ucsd.edu/dc/object/bb01069785
# 2018_03_12
# https://library.ucsd.edu/dc/object/bb2222428k
# 2018_03_05
# https://library.ucsd.edu/dc/object/bb29050275
# 2018_02_26
# https://library.ucsd.edu/dc/object/bb3587627n
# 2018_02_20
# https://library.ucsd.edu/dc/object/bb4270229w
# 2018_02_12
# https://library.ucsd.edu/dc/object/bb4918699h
# 2018_02_05
# https://library.ucsd.edu/dc/object/bb5601295n
# 2018_01_29
# https://library.ucsd.edu/dc/object/bb62838996
# 2018_01_22
# https://library.ucsd.edu/dc/object/bb6932369m
# 2018_01_16
# https://library.ucsd.edu/dc/object/bb7614967m
# 2018_01_08
# https://library.ucsd.edu/dc/object/bb8297568j
# 2017_12_04
# https://library.ucsd.edu/dc/object/bb8946038z
# 2017_11_27
# https://library.ucsd.edu/dc/object/bb96286380
# 2017_11_20
# https://library.ucsd.edu/dc/object/bb0311145k
# 2017_11_13
# https://library.ucsd.edu/dc/object/bb0959616s
# 2017_11_06
# https://library.ucsd.edu/dc/object/bb16422181
# 2017_10_30
# https://library.ucsd.edu/dc/object/bb5607981q
# 2017_10_24
# https://library.ucsd.edu/dc/object/bb23248161
# 2017_10_23
# https://library.ucsd.edu/dc/object/bb29732868
# 2017_10_16
# https://library.ucsd.edu/dc/object/bb36558869
# 2017_10_09
# https://library.ucsd.edu/dc/object/bb68982352
# 2017_10_02
# https://library.ucsd.edu/dc/object/bb1743391g
# 2017_06_06
# https://library.ucsd.edu/dc/object/bb10949226
# 2017_05_30
# https://library.ucsd.edu/dc/object/bb0412322q
# 2017_05_22
# https://library.ucsd.edu/dc/object/bb97298112
# 2017_05_14
# https://library.ucsd.edu/dc/object/bb9081342b
# 2017_05_01
# https://library.ucsd.edu/dc/object/bb8398743n
# 2017_04_17
# https://library.ucsd.edu/dc/object/bb77161414
# 2017_04_10
# https://library.ucsd.edu/dc/object/bb70335432
# 2017_04_03
# https://library.ucsd.edu/dc/object/bb6385073q
# 2017_03_13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 20
#      17 # Loop through all the subpages and scrape the PDF links
#      18 for subpage_link in subpage_links:
#      19     # Make a GET request to the subpage URL
# ---> 20     response = requests.get(subpage_link)
#      22     # Create a BeautifulSoup object from the response HTML
#      23     soup = BeautifulSoup(response.content, 'html.parser')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:
