# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import json

def get_subpages(base_url):
    # Define the range of subpage numbers to extract links from
    start_page = 1
    end_page = 582

    # Initialize an empty list to store the links
    links = []
    subpage_pattern = 'page/{}'

    # Loop over the subpage numbers and extract the links
    for page_num in range(start_page, end_page+1):
        # Construct the URL for the current subpage
        url = base_url + subpage_pattern.format(page_num) + "/"
        links.append(url)

    return links

def get_article_links_and_dates(url):
    # Send a request to the URL and get the HTML response
    response = requests.get(url)
    html = response.text

    # Parse the HTML with BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    # Find all the div elements with class "item-details"
    item_details = soup.find_all('div', class_='item-details')

    # Initialize an empty dictionary to store the links and dates
    link_date_dict = {}

    # Loop over each "item-details" div and extract the link and date
    for item in item_details:
        link = item.find('a')['href']
        date_str = item.find('time')['datetime']

        # Convert the date string to a datetime object
        date = datetime.fromisoformat(date_str[:-6])

        # Format the datetime object as YYYY_mm_dd
        formatted_date = date.strftime('%Y_%m_%d')

        # Add the link to the dictionary
        if formatted_date in link_date_dict:
            link_date_dict[formatted_date].append(link)
        else:
            link_date_dict[formatted_date] = [link]

    return link_date_dict

# %%
# Define the base URL of the subpages
base_url = 'https://knightnews.com/category/news/'

# Get the links of all subpages
subpage_links = get_subpages(base_url)

# Initialize an empty dictionary to store links and dates
all_links_dates = {}

# Loop over all subpages, extract links and dates and store in the dictionaries
for subpage_url in subpage_links:
    links_dates_dict = get_article_links_and_dates(subpage_url)
    all_links_dates.update(links_dates_dict)

# Write the dictionary to a JSON file
with open('ucf_article_pages.json', 'w') as f:
    json.dump(all_links_dates, f, indent=4)

    ## Note ## 
    # Duplicates of the first three links were manually removed in 'ucf_article_pages.json'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#      10 # Loop over all subpages, extract links and dates and store in the dictionaries
#      11 for subpage_url in subpage_links:
# ---> 12     links_dates_dict = get_article_links_and_dates(subpage_url)
#      13     all_links_dates.update(links_dates_dict)
#      15 # Write the dictionary to a JSON file
#
# Cell In[8], line 25, in get_article_links_and_dates(url)
#      23 def get_article_links_and_dates(url):
#      24     # Send a request to the URL and get the HTML response
# ---> 25     response = requests.get(url)
#      26     html = response.text
#      28     # Parse the HTML with BeautifulSoup
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from helpers.txt_to_text import get_article_text
from helpers.make_txt_entry import make_txt_entry
import os
import json 

# Open the JSON file
with open('ucf_article_pages.json', 'r') as f:
    all_links_dates = json.load(f)

school_name = "UCF"
dates = sorted(all_links_dates.keys())

for date in reversed(dates):
    articles = all_links_dates[date]
    file_path = "journal_data/txt/"+school_name.replace(" ","_")+"/"+date+".txt"
    if(os.path.exists(file_path)):
        print(f"Date {date} already added.")
    else:
        article_text = ""
        for article in articles:
            article_text += get_article_text(article) + "\n"
            
        make_txt_entry(school_name="UCF", publication_date=date, text=article_text)
        print(f"Date {date} added.")

    ## Note ## 
    # Two outlier entries from 2000 were manually removed
# Out:
# Date 2023_04_22 already added.
# Date 2023_04_08 already added.
# Date 2023_04_03 already added.
# Date 2023_03_23 already added.
# Date 2023_03_22 already added.
# Date 2023_03_17 already added.
# Date 2023_03_13 already added.
# Date 2023_03_12 already added.
# Date 2023_03_08 already added.
# Date 2023_02_21 already added.
# Date 2023_02_20 already added.
# Date 2023_02_04 already added.
# Date 2022_12_15 already added.
# Date 2022_12_08 already added.
# Date 2022_12_06 already added.
# Date 2022_11_14 already added.
# Date 2022_11_08 already added.
# Date 2022_11_07 already added.
# Date 2022_11_03 already added.
# Date 2022_10_26 already added.
# Date 2022_10_24 already added.
# Date 2022_10_22 already added.
# Date 2022_10_19 already added.
# Date 2022_10_12 already added.
# Date 2022_10_06 already added.
# Date 2022_10_02 already added.
# Date 2022_09_30 already added.
# Date 2022_09_29 already added.
# Date 2022_09_28 already added.
# Date 2022_09_27 already added.
# Date 2022_09_26 already added.
# Date 2022_09_25 already added.
# Date 2022_09_23 already added.
# Date 2022_09_21 already added.
# Date 2022_09_20 already added.
# Date 2022_09_19 already added.
# Date 2022_09_16 already added.
# Date 2022_09_15 already added.
# Date 2022_09_14 already added.
# Date 2022_09_13 already added.
# Date 2022_09_12 already added.
# Date 2022_09_10 already added.
# Date 2022_09_08 already added.
# Date 2022_09_06 already added.
# Date 2022_09_02 already added.
# Date 2022_08_31 already added.
# Date 2022_08_30 already added.
# Date 2022_08_29 already added.
# Date 2022_08_27 already added.
# Date 2022_08_26 already added.
# Date 2022_08_25 already added.
# Date 2022_08_24 already added.
# Date 2022_08_22 already added.
# Date 2022_08_19 already added.
# Date 2022_08_18 already added.
# Date 2022_08_17 already added.
# Date 2022_08_16 already added.
# Date 2022_08_12 already added.
# Date 2022_08_11 already added.
# Date 2022_08_10 already added.
# Date 2022_07_28 already added.
# Date 2022_07_27 already added.
# Date 2022_07_26 already added.
# Date 2022_07_25 already added.
# Date 2022_07_21 already added.
# Date 2022_07_20 already added.
# Date 2022_07_18 already added.
# Date 2022_07_14 already added.
# Date 2022_07_13 already added.
# Date 2022_07_01 already added.
# Date 2022_06_29 already added.
# Date 2022_06_28 already added.
# Date 2022_06_24 already added.
# Date 2022_06_18 already added.
# Date 2022_06_17 already added.
# Date 2022_06_16 already added.
# Date 2022_06_14 already added.
# Date 2022_06_13 already added.
# Date 2022_06_09 already added.
# Date 2022_06_08 already added.
# Date 2022_06_07 already added.
# Date 2022_06_03 already added.
# Date 2022_06_02 already added.
# Date 2022_05_28 already added.
# Date 2022_05_27 already added.
# Date 2022_05_26 already added.
# Date 2022_05_25 already added.
# Date 2022_05_13 already added.
# Date 2022_05_10 already added.
# Date 2022_05_09 already added.
# Date 2022_05_02 already added.
# Date 2022_04_30 already added.
# Date 2022_04_25 already added.
# Date 2022_04_22 already added.
# Date 2022_04_16 already added.
# Date 2022_04_15 already added.
# Date 2022_04_14 already added.
# Date 2022_04_10 already added.
# Date 2022_04_08 already added.
# Date 2022_04_07 already added.
# Date 2022_04_04 already added.
# Date 2022_04_03 already added.
# Date 2022_03_31 already added.
# Date 2022_03_25 already added.
# Date 2022_03_20 already added.
# Date 2022_03_14 already added.
# Date 2022_03_13 already added.
# Date 2022_03_09 already added.
# Date 2022_03_04 already added.
# Date 2022_03_03 already added.
# Date 2022_03_02 already added.
# Date 2022_02_25 already added.
# Date 2022_02_23 already added.
# Date 2022_02_21 already added.
# Date 2022_02_15 already added.
# Date 2022_02_14 already added.
# Date 2022_02_11 already added.
# Date 2022_02_07 already added.
# Date 2022_02_04 already added.
# Date 2022_02_03 already added.
# Date 2022_01_31 already added.
# Date 2022_01_28 already added.
# Date 2022_01_27 already added.
# Date 2022_01_24 already added.
# Date 2022_01_17 already added.
# Date 2022_01_16 already added.
# Date 2022_01_10 already added.
# Date 2022_01_09 already added.
# Date 2022_01_05 already added.
# Date 2022_01_03 already added.
# Date 2021_12_20 already added.
# Date 2021_12_16 already added.
# Date 2021_12_01 already added.
# Date 2021_11_26 already added.
# Date 2021_11_20 already added.
# Date 2021_11_19 already added.
# Date 2021_11_18 already added.
# Date 2021_11_17 already added.
# Date 2021_11_10 already added.
# Date 2021_11_06 already added.
# Date 2021_11_05 already added.
# Date 2021_11_03 already added.
# Date 2021_11_01 already added.
# Date 2021_10_24 already added.
# Date 2021_10_22 already added.
# Date 2021_10_20 already added.
# Date 2021_10_17 already added.
# Date 2021_10_15 already added.
# Date 2021_10_09 already added.
# Date 2021_10_08 already added.
# Date 2021_10_05 already added.
# Date 2021_10_02 already added.
# Date 2021_09_27 already added.
# Date 2021_09_24 already added.
# Date 2021_09_19 already added.
# Date 2021_09_18 already added.
# Date 2021_09_16 already added.
# Date 2021_09_15 already added.
# Date 2021_09_14 already added.
# Date 2021_09_12 already added.
# Date 2021_09_11 already added.
# Date 2021_09_10 already added.
# Date 2021_09_09 already added.
# Date 2021_09_03 already added.
# Date 2021_08_31 already added.
# Date 2021_08_29 already added.
# Date 2021_08_23 already added.
# Date 2021_08_09 already added.
# Date 2021_07_28 already added.
# Date 2021_07_23 already added.
# Date 2021_07_20 already added.
# Date 2021_07_07 already added.
# Date 2021_07_06 already added.
# Date 2021_07_05 already added.
# Date 2021_06_24 already added.
# Date 2021_06_18 already added.
# Date 2021_05_26 already added.
# Date 2021_05_18 already added.
# Date 2021_05_16 already added.
# Date 2021_05_15 already added.
# Date 2021_05_13 already added.
# Date 2021_05_12 already added.
# Date 2021_05_07 already added.
# Date 2021_05_06 already added.
# Date 2021_05_03 already added.
# Date 2021_05_02 already added.
# Date 2021_04_30 already added.
# Date 2021_04_28 already added.
# Date 2021_04_27 already added.
# Date 2021_04_25 already added.
# Date 2021_04_17 already added.
# Date 2021_04_12 already added.
# Date 2021_04_11 already added.
# Date 2021_04_08 already added.
# Date 2021_04_06 already added.
# Date 2021_03_31 already added.
# Date 2021_03_29 already added.
# Date 2021_03_28 already added.
# Date 2021_03_26 already added.
# Date 2021_03_22 already added.
# Date 2021_03_21 already added.
# Date 2021_03_20 already added.
# Date 2021_03_17 already added.
# Date 2021_03_16 already added.
# Date 2021_03_14 already added.
# Date 2021_03_13 already added.
# Date 2021_03_09 already added.
# Date 2021_03_08 already added.
# Date 2021_03_07 already added.
# Date 2021_03_03 already added.
# Date 2021_03_02 already added.
# Date 2021_03_01 already added.
# Date 2021_02_26 already added.
# Date 2021_02_22 already added.
# Date 2021_02_19 already added.
# Date 2021_02_18 already added.
# Date 2021_02_17 already added.
# Date 2021_02_15 already added.
# Date 2021_02_14 already added.
# Date 2021_02_12 already added.
# Date 2021_02_10 already added.
# Date 2021_02_09 already added.
# Date 2021_02_08 already added.
# Date 2021_02_07 already added.
# Date 2021_01_31 already added.
# Date 2021_01_27 already added.
# Date 2021_01_26 already added.
# Date 2021_01_23 already added.
# Date 2021_01_22 already added.
# Date 2021_01_21 already added.
# Date 2021_01_20 already added.
# Date 2021_01_13 already added.
# Date 2021_01_11 already added.
# Date 2021_01_10 already added.
# Date 2021_01_07 already added.
# Date 2021_01_05 already added.
# Date 2021_01_03 already added.
# Date 2020_12_30 already added.
# Date 2020_12_29 already added.
# Date 2020_12_26 already added.
# Date 2020_12_23 already added.
# Date 2020_12_20 already added.
# Date 2020_12_18 already added.
# Date 2020_12_17 already added.
# Date 2020_12_16 already added.
# Date 2020_12_12 already added.
# Date 2020_12_11 already added.
# Date 2020_12_10 already added.
# Date 2020_12_07 already added.
# Date 2020_12_03 already added.
# Date 2020_12_02 already added.
# Date 2020_12_01 already added.
# Date 2020_11_27 already added.
# Date 2020_11_26 already added.
# Date 2020_11_25 already added.
# Date 2020_11_23 already added.
# Date 2020_11_21 already added.
# Date 2020_11_20 already added.
# Date 2020_11_19 already added.
# Date 2020_11_16 already added.
# Date 2020_11_14 already added.
# Date 2020_11_12 already added.
# Date 2020_11_11 already added.
# Date 2020_11_09 already added.
# Date 2020_11_05 already added.
# Date 2020_11_04 already added.
# Date 2020_11_02 already added.
# Date 2020_10_31 already added.
# Date 2020_10_26 already added.
# Date 2020_10_24 already added.
# Date 2020_10_23 already added.
# Date 2020_10_22 already added.
# Date 2020_10_21 already added.
# Date 2020_10_16 already added.
# Date 2020_10_12 already added.
# Date 2020_10_09 already added.
# Date 2020_10_05 already added.
# Date 2020_09_28 already added.
# Date 2020_09_23 already added.
# Date 2020_09_22 already added.
# Date 2020_09_21 already added.
# Date 2020_09_19 already added.
# Date 2020_09_18 already added.
# Date 2020_09_17 already added.
# Date 2020_09_16 already added.
# Date 2020_09_14 already added.
# Date 2020_09_11 already added.
# Date 2020_09_10 already added.
# Date 2020_09_08 already added.
# Date 2020_09_06 already added.
# Date 2020_09_05 already added.
# Date 2020_09_04 already added.
# Date 2020_09_03 already added.
# Date 2020_09_01 already added.
# Date 2020_08_31 already added.
# Date 2020_08_26 already added.
# Date 2020_08_24 already added.
# Date 2020_08_22 already added.
# Date 2020_08_18 already added.
# Date 2020_08_12 already added.
# Date 2020_08_06 already added.
# Date 2020_08_01 already added.
# Date 2020_07_22 already added.
# Date 2020_07_21 already added.
# Date 2020_07_16 already added.
# Date 2020_07_14 already added.
# Date 2020_07_11 already added.
# Date 2020_07_02 already added.
# Date 2020_06_24 already added.
# Date 2020_06_23 already added.
# Date 2020_06_22 already added.
# Date 2020_06_17 already added.
# Date 2020_06_15 already added.
# Date 2020_06_12 already added.
# Date 2020_06_10 already added.
# Date 2020_06_09 already added.
# Date 2020_06_07 already added.
# Date 2020_06_04 already added.
# Date 2020_06_01 already added.
# Date 2020_05_22 already added.
# Date 2020_05_21 already added.
# Date 2020_05_20 already added.
# Date 2020_05_15 already added.
# Date 2020_05_13 already added.
# Date 2020_05_12 already added.
# Date 2020_05_10 already added.
# Date 2020_05_07 already added.
# Date 2020_05_06 already added.
# Date 2020_05_02 already added.
# Date 2020_05_01 already added.
# Date 2020_04_20 already added.
# Date 2020_04_13 already added.
# Date 2020_04_12 already added.
# Date 2020_04_11 already added.
# Date 2020_04_09 already added.
# Date 2020_04_07 already added.
# Date 2020_04_06 already added.
# Date 2020_04_05 already added.
# Date 2020_04_02 already added.
# Date 2020_04_01 already added.
# Date 2020_03_31 already added.
# Date 2020_03_30 already added.
# Date 2020_03_25 already added.
# Date 2020_03_24 already added.
# Date 2020_03_23 already added.
# Date 2020_03_22 already added.
# Date 2020_03_20 already added.
# Date 2020_03_19 already added.
# Date 2020_03_18 already added.
# Date 2020_03_17 already added.
# Date 2020_03_15 already added.
# Date 2020_03_14 already added.
# Date 2020_03_13 already added.
# Date 2020_03_12 already added.
# Date 2020_03_10 already added.
# Date 2020_03_09 already added.
# Date 2020_03_08 already added.
# Date 2020_03_06 already added.
# Date 2020_03_03 already added.
# Date 2020_03_02 already added.
# Date 2020_02_27 already added.
# Date 2020_02_26 already added.
# Date 2020_02_25 already added.
# Date 2020_02_23 already added.
# Date 2020_02_18 already added.
# Date 2020_02_13 already added.
# Date 2020_02_10 already added.
# Date 2020_02_08 already added.
# Date 2020_02_07 already added.
# Date 2020_02_05 already added.
# Date 2020_02_02 already added.
# Date 2020_01_31 already added.
# Date 2020_01_30 already added.
# Date 2020_01_29 already added.
# Date 2020_01_27 already added.
# Date 2020_01_26 already added.
# Date 2020_01_24 already added.
# Date 2020_01_21 already added.
# Date 2020_01_20 already added.
# Date 2020_01_14 already added.
# Date 2020_01_11 already added.
# Date 2020_01_10 already added.
# Date 2020_01_06 already added.
# Date 2020_01_04 already added.
# Date 2019_12_23 already added.
# Date 2019_12_19 already added.
# Date 2019_12_11 already added.
# Date 2019_12_09 already added.
# Date 2019_12_08 already added.
# Date 2019_12_06 already added.
# Date 2019_12_05 already added.
# Date 2019_12_03 already added.
# Date 2019_12_02 already added.
# Date 2019_12_01 already added.
# Date 2019_11_30 already added.
# Date 2019_11_29 already added.
# Date 2019_11_28 already added.
# Date 2019_11_27 already added.
# Date 2019_11_26 already added.
# Date 2019_11_25 already added.
# Date 2019_11_23 already added.
# Date 2019_11_22 already added.
# Date 2019_11_21 already added.
# Date 2019_11_18 already added.
# Date 2019_11_15 already added.
# Date 2019_11_14 already added.
# Date 2019_11_13 already added.
# Date 2019_11_11 already added.
# Date 2019_11_10 already added.
# Date 2019_11_09 already added.
# Date 2019_11_06 already added.
# Date 2019_11_05 already added.
# Date 2019_11_04 already added.
# Date 2019_11_03 already added.
# Date 2019_11_02 already added.
# Date 2019_10_29 already added.
# Date 2019_10_27 already added.
# Date 2019_10_25 already added.
# Date 2019_10_24 already added.
# Date 2019_10_23 already added.
# Date 2019_10_22 already added.
# Date 2019_10_21 already added.
# Date 2019_10_20 already added.
# Date 2019_10_18 already added.
# Date 2019_10_14 already added.
# Date 2019_10_13 already added.
# Date 2019_10_11 already added.
# Date 2019_10_10 already added.
# Date 2019_10_08 already added.
# Date 2019_10_07 already added.
# Date 2019_10_06 already added.
# Date 2019_10_04 already added.
# Date 2019_10_02 already added.
# Date 2019_10_01 already added.
# Date 2019_09_30 already added.
# Date 2019_09_28 already added.
# Date 2019_09_26 already added.
# Date 2019_09_25 already added.
# Date 2019_09_24 already added.
# Date 2019_09_23 already added.
# Date 2019_09_22 already added.
# Date 2019_09_21 already added.
# Date 2019_09_18 already added.
# Date 2019_09_16 already added.
# Date 2019_09_15 already added.
# Date 2019_09_14 already added.
# Date 2019_09_12 already added.
# Date 2019_09_10 already added.
# Date 2019_09_09 already added.
# Date 2019_09_08 already added.
# Date 2019_09_07 already added.
# Date 2019_09_06 already added.
# Date 2019_09_05 already added.
# Date 2019_09_04 already added.
# Date 2019_09_03 already added.
# Date 2019_09_01 already added.
# Date 2019_08_30 already added.
# Date 2019_08_29 already added.
# Date 2019_08_28 already added.
# Date 2019_08_27 already added.
# Date 2019_08_25 already added.
# Date 2019_08_23 already added.
# Date 2019_08_22 already added.
# Date 2019_08_21 already added.
# Date 2019_08_19 already added.
# Date 2019_08_18 already added.
# Date 2019_08_17 already added.
# Date 2019_08_16 already added.
# Date 2019_08_15 already added.
# Date 2019_08_12 already added.
# Date 2019_08_10 already added.
# Date 2019_08_07 already added.
# Date 2019_07_30 already added.
# Date 2019_07_27 already added.
# Date 2019_07_25 already added.
# Date 2019_07_22 already added.
# Date 2019_07_20 already added.
# Date 2019_07_15 already added.
# Date 2019_07_13 already added.
# Date 2019_07_10 already added.
# Date 2019_07_09 already added.
# Date 2019_07_05 already added.
# Date 2019_07_03 already added.
# Date 2019_07_02 already added.
# Date 2019_07_01 already added.
# Date 2019_06_28 already added.
# Date 2019_06_27 already added.
# Date 2019_06_26 already added.
# Date 2019_06_25 already added.
# Date 2019_06_22 already added.
# Date 2019_06_21 already added.
# Date 2019_06_19 already added.
# Date 2019_06_17 already added.
# Date 2019_06_14 already added.
# Date 2019_06_13 already added.
# Date 2019_06_11 already added.
# Date 2019_06_06 already added.
# Date 2019_06_04 already added.
# Date 2019_06_02 already added.
# Date 2019_06_01 already added.
# Date 2019_05_25 already added.
# Date 2019_05_22 already added.
# Date 2019_05_16 already added.
# Date 2019_05_11 already added.
# Date 2019_05_08 already added.
# Date 2019_05_04 already added.
# Date 2019_04_30 already added.
# Date 2019_04_29 already added.
# Date 2019_04_26 already added.
# Date 2019_04_24 already added.
# Date 2019_04_23 already added.
# Date 2019_04_19 already added.
# Date 2019_04_18 already added.
# Date 2019_04_10 already added.
# Date 2019_04_09 already added.
# Date 2019_04_08 already added.
# Date 2019_04_06 already added.
# Date 2019_04_04 already added.
# Date 2019_04_03 already added.
# Date 2019_03_30 already added.
# Date 2019_03_26 already added.
# Date 2019_03_24 already added.
# Date 2019_03_22 already added.
# Date 2019_03_21 already added.
# Date 2019_03_20 already added.
# Date 2019_03_17 already added.
# Date 2019_03_15 already added.
# Date 2019_03_12 already added.
# Date 2019_03_11 already added.
# Date 2019_03_10 already added.
# Date 2019_03_08 already added.
# Date 2019_03_07 already added.
# Date 2019_03_06 already added.
# Date 2019_03_04 already added.
# Date 2019_03_02 already added.
# Date 2019_02_28 already added.
# Date 2019_02_26 already added.
# Date 2019_02_25 already added.
# Date 2019_02_24 already added.
# Date 2019_02_23 already added.
# Date 2019_02_22 already added.
# Date 2019_02_21 already added.
# Date 2019_02_20 already added.
# Date 2019_02_19 already added.
# Date 2019_02_18 already added.
# Date 2019_02_16 already added.
# Date 2019_02_14 already added.
# Date 2019_02_13 already added.
# Date 2019_02_10 already added.
# Date 2019_02_09 already added.
# Date 2019_02_07 already added.
# Date 2019_02_06 already added.
# Date 2019_02_04 already added.
# Date 2019_02_02 already added.
# Date 2019_02_01 already added.
# Date 2019_01_31 already added.
# Date 2019_01_30 already added.
# Date 2019_01_29 already added.
# Date 2019_01_28 already added.
# Date 2019_01_27 already added.
# Date 2019_01_26 already added.
# Date 2019_01_24 already added.
# Date 2019_01_23 already added.
# Date 2019_01_22 already added.
# Date 2019_01_21 already added.
# Date 2019_01_20 already added.
# Date 2019_01_19 already added.
# Date 2019_01_18 already added.
# Date 2019_01_17 already added.
# Date 2019_01_15 already added.
# Date 2019_01_14 already added.
# Date 2019_01_09 already added.
# Date 2019_01_08 already added.
# Date 2019_01_07 already added.
# Date 2019_01_05 already added.
# Date 2019_01_03 already added.
# Date 2019_01_01 already added.
# Date 2018_12_31 already added.
# Date 2018_12_30 already added.
# Date 2018_12_29 already added.
# Date 2018_12_27 already added.
# Date 2018_12_25 already added.
# Date 2018_12_22 already added.
# Date 2018_12_20 already added.
# Date 2018_12_19 already added.
# Date 2018_12_17 already added.
# Date 2018_12_14 already added.
# Date 2018_12_12 already added.
# Date 2018_12_11 already added.
# Date 2018_12_10 already added.
# Date 2018_12_07 already added.
# Date 2018_12_06 already added.
# Date 2018_12_05 already added.
# Date 2018_12_03 already added.
# Date 2018_12_02 already added.
# Date 2018_12_01 already added.
# Date 2018_11_29 already added.
# Date 2018_11_27 already added.
# Date 2018_11_26 already added.
# Date 2018_11_24 already added.
# Date 2018_11_23 already added.
# Date 2018_11_20 already added.
# Date 2018_11_19 already added.
# Date 2018_11_18 already added.
# Date 2018_11_17 already added.
# Date 2018_11_16 already added.
# Date 2018_11_15 already added.
# Date 2018_11_12 already added.
# Date 2018_11_11 already added.
# Date 2018_11_10 already added.
# Date 2018_11_09 already added.
# Date 2018_11_08 already added.
# Date 2018_11_06 already added.
# Date 2018_11_04 already added.
# Date 2018_11_03 already added.
# Date 2018_11_01 already added.
# Date 2018_10_31 already added.
# Date 2018_10_30 already added.
# Date 2018_10_29 already added.
# Date 2018_10_27 already added.
# Date 2018_10_25 already added.
# Date 2018_10_21 already added.
# Date 2018_10_18 already added.
# Date 2018_10_17 already added.
# Date 2018_10_16 already added.
# Date 2018_10_13 already added.
# Date 2018_10_11 already added.
# Date 2018_10_10 already added.
# Date 2018_10_08 already added.
# Date 2018_10_07 already added.
# Date 2018_10_06 already added.
# Date 2018_10_05 already added.
# Date 2018_10_01 already added.
# Date 2018_09_29 already added.
# Date 2018_09_27 already added.
# Date 2018_09_26 already added.
# Date 2018_09_25 already added.
# Date 2018_09_23 already added.
# Date 2018_09_22 already added.
# Date 2018_09_21 already added.
# Date 2018_09_20 already added.
# Date 2018_09_19 already added.
# Date 2018_09_18 already added.
# Date 2018_09_17 already added.
# Date 2018_09_14 already added.
# Date 2018_09_13 already added.
# Date 2018_09_11 already added.
# Date 2018_09_10 already added.
# Date 2018_09_09 already added.
# Date 2018_09_08 already added.
# Date 2018_09_07 already added.
# Date 2018_09_05 already added.
# Date 2018_09_04 already added.
# Date 2018_09_02 already added.
# Date 2018_08_30 already added.
# Date 2018_08_29 already added.
# Date 2018_08_27 already added.
# Date 2018_08_26 already added.
# Date 2018_08_25 already added.
# Date 2018_08_24 already added.
# Date 2018_08_23 already added.
# Date 2018_08_22 already added.
# Date 2018_08_21 already added.
# Date 2018_08_20 already added.
# Date 2018_08_17 already added.
# Date 2018_08_16 already added.
# Date 2018_07_30 already added.
# Date 2018_07_27 already added.
# Date 2018_07_25 already added.
# Date 2018_07_24 already added.
# Date 2018_07_21 already added.
# Date 2018_07_13 already added.
# Date 2018_07_10 already added.
# Date 2018_07_04 already added.
# Date 2018_07_03 already added.
# Date 2018_07_02 already added.
# Date 2018_06_28 already added.
# Date 2018_06_24 already added.
# Date 2018_06_17 already added.
# Date 2018_06_16 already added.
# Date 2018_06_15 already added.
# Date 2018_06_13 already added.
# Date 2018_06_12 already added.
# Date 2018_06_07 already added.
# Date 2018_06_05 already added.
# Date 2018_06_01 already added.
# Date 2018_05_26 already added.
# Date 2018_05_25 already added.
# Date 2018_05_24 already added.
# Date 2018_05_21 already added.
# Date 2018_05_18 already added.
# Date 2018_05_17 already added.
# Date 2018_05_14 already added.
# Date 2018_05_11 already added.
# Date 2018_05_10 already added.
# Date 2018_05_07 already added.
# Date 2018_05_06 already added.
# Date 2018_05_05 already added.
# Date 2018_05_03 already added.
# Date 2018_04_30 already added.
# Date 2018_04_28 already added.
# Date 2018_04_27 already added.
# Date 2018_04_26 already added.
# Date 2018_04_25 already added.
# Date 2018_04_23 already added.
# Date 2018_04_22 already added.
# Date 2018_04_21 already added.
# Date 2018_04_20 already added.
# Date 2018_04_19 already added.
# Date 2018_04_12 already added.
# Date 2018_04_11 already added.
# Date 2018_04_10 already added.
# Date 2018_04_08 already added.
# Date 2018_04_07 already added.
# Date 2018_04_05 already added.
# Date 2018_04_04 already added.
# Date 2018_03_31 already added.
# Date 2018_03_29 already added.
# Date 2018_03_28 already added.
# Date 2018_03_24 already added.
# Date 2018_03_22 already added.
# Date 2018_03_19 already added.
# Date 2018_03_15 already added.
# Date 2018_03_14 already added.
# Date 2018_03_11 already added.
# Date 2018_03_09 already added.
# Date 2018_03_08 already added.
# Date 2018_03_07 already added.
# Date 2018_03_06 already added.
# Date 2018_03_05 already added.
# Date 2018_03_04 already added.
# Date 2018_03_03 already added.
# Date 2018_03_02 already added.
# Date 2018_02_28 already added.
# Date 2018_02_27 already added.
# Date 2018_02_23 already added.
# Date 2018_02_22 already added.
# Date 2018_02_21 already added.
# Date 2018_02_20 already added.
# Date 2018_02_19 already added.
# Date 2018_02_17 already added.
# Date 2018_02_15 already added.
# Date 2018_02_14 already added.
# Date 2018_02_13 already added.
# Date 2018_02_12 already added.
# Date 2018_02_10 already added.
# Date 2018_02_09 already added.
# Date 2018_02_08 already added.
# Date 2018_02_07 already added.
# Date 2018_02_05 already added.
# Date 2018_02_04 already added.
# Date 2018_02_02 already added.
# Date 2018_02_01 already added.
# Date 2018_01_31 already added.
# Date 2018_01_30 already added.
# Date 2018_01_27 already added.
# Date 2018_01_26 already added.
# Date 2018_01_25 already added.
# Date 2018_01_24 already added.
# Date 2018_01_23 already added.
# Date 2018_01_22 already added.
# Date 2018_01_21 already added.
# Date 2018_01_20 already added.
# Date 2018_01_16 already added.
# Date 2018_01_15 already added.
# Date 2018_01_14 already added.
# Date 2018_01_13 already added.
# Date 2018_01_11 already added.
# Date 2018_01_10 already added.
# Date 2018_01_09 already added.
# Date 2018_01_08 already added.
# Date 2018_01_07 already added.
# Date 2018_01_06 already added.
# Date 2018_01_05 already added.
# Date 2018_01_04 already added.
# Date 2018_01_03 already added.
# Date 2018_01_02 already added.
# Date 2018_01_01 already added.
# Date 2017_12_31 already added.
# Date 2017_12_30 already added.
# Date 2017_12_29 already added.
# Date 2017_12_28 already added.
# Date 2017_12_21 already added.
# Date 2017_12_13 already added.
# Date 2017_12_12 already added.
# Date 2017_12_09 already added.
# Date 2017_12_08 already added.
# Date 2017_12_07 already added.
# Date 2017_12_06 already added.
# Date 2017_12_05 already added.
# Date 2017_12_04 already added.
# Date 2017_12_03 already added.
# Date 2017_12_02 already added.
# Date 2017_12_01 already added.
# Date 2017_11_30 already added.
# Date 2017_11_29 already added.
# Date 2017_11_28 already added.
# Date 2017_11_26 already added.
# Date 2017_11_25 already added.
# Date 2017_11_24 already added.
# Date 2017_11_23 already added.
# Date 2017_11_22 already added.
# Date 2017_11_21 already added.
# Date 2017_11_20 already added.
# Date 2017_11_19 already added.
# Date 2017_11_18 already added.
# Date 2017_11_17 already added.
# Date 2017_11_16 already added.
# Date 2017_11_14 already added.
# Date 2017_11_13 already added.
# Date 2017_11_12 already added.
# Date 2017_11_11 already added.
# Date 2017_11_10 already added.
# Date 2017_11_09 already added.
# Date 2017_11_08 already added.
# Date 2017_11_07 already added.
# Date 2017_11_06 already added.
# Date 2017_11_05 already added.
# Date 2017_11_04 already added.
# Date 2017_11_03 already added.
# Date 2017_11_01 already added.
# Date 2017_10_31 already added.
# Date 2017_10_29 already added.
# Date 2017_10_28 already added.
# Date 2017_10_26 already added.
# Date 2017_10_25 already added.
# Date 2017_10_24 already added.
# Date 2017_10_23 already added.
# Date 2017_10_22 already added.
# Date 2017_10_21 already added.
# Date 2017_10_20 already added.
# Date 2017_10_19 already added.
# Date 2017_10_18 already added.
# Date 2017_10_17 already added.
# Date 2017_10_15 already added.
# Date 2017_10_14 already added.
# Date 2017_10_13 already added.
# Date 2017_10_12 already added.
# Date 2017_10_09 already added.
# Date 2017_10_08 already added.
# Date 2017_10_07 already added.
# Date 2017_10_06 already added.
# Date 2017_10_04 already added.
# Date 2017_10_02 already added.
# Date 2017_10_01 already added.
# Date 2017_09_30 already added.
# Date 2017_09_29 already added.
# Date 2017_09_28 already added.
# Date 2017_09_27 already added.
# Date 2017_09_26 already added.
# Date 2017_09_25 already added.
# Date 2017_09_23 already added.
# Date 2017_09_21 already added.
# Date 2017_09_20 already added.
# Date 2017_09_19 already added.
# Date 2017_09_18 already added.
# Date 2017_09_16 already added.
# Date 2017_09_15 already added.
# Date 2017_09_14 already added.
# Date 2017_09_13 already added.
# Date 2017_09_12 already added.
# Date 2017_09_11 already added.
# Date 2017_09_10 already added.
# Date 2017_09_09 already added.
# Date 2017_09_08 already added.
# Date 2017_09_07 already added.
# Date 2017_09_06 already added.
# Date 2017_09_05 already added.
# Date 2017_09_04 already added.
# Date 2017_09_03 already added.
# Date 2017_08_31 already added.
# Date 2017_08_30 already added.
# Date 2017_08_29 already added.
# Date 2017_08_26 already added.
# Date 2017_08_25 already added.
# Date 2017_08_24 already added.
# Date 2017_08_22 already added.
# Date 2017_08_21 already added.
# Date 2017_08_20 already added.
# Date 2017_08_19 already added.
# Date 2017_08_16 already added.
# Date 2017_08_08 already added.
# Date 2017_08_05 already added.
# Date 2017_08_04 already added.
# Date 2017_08_01 already added.
# Date 2017_07_31 already added.
# Date 2017_07_27 already added.
# Date 2017_07_25 already added.
# Date 2017_07_24 already added.
# Date 2017_07_23 already added.
# Date 2017_07_19 already added.
# Date 2017_07_12 already added.
# Date 2017_07_10 already added.
# Date 2017_07_05 already added.
# Date 2017_06_30 already added.
# Date 2017_06_27 already added.
# Date 2017_06_26 already added.
# Date 2017_06_25 already added.
# Date 2017_06_24 already added.
# Date 2017_06_20 already added.
# Date 2017_06_19 already added.
# Date 2017_06_18 already added.
# Date 2017_06_15 already added.
# Date 2017_06_14 already added.
# Date 2017_06_12 already added.
# Date 2017_06_08 already added.
# Date 2017_06_06 already added.
# Date 2017_05_24 already added.
# Date 2017_05_23 already added.
# Date 2017_05_18 already added.
# Date 2017_05_14 already added.
# Date 2017_05_13 already added.
# Date 2017_05_12 already added.
# Date 2017_05_10 already added.
# Date 2017_05_08 already added.
# Date 2017_05_04 already added.
# Date 2017_05_02 already added.
# Date 2017_04_28 already added.
# Date 2017_04_26 already added.
# Date 2017_04_24 already added.
# Date 2017_04_23 already added.
# Date 2017_04_22 already added.
# Date 2017_04_20 already added.
# Date 2017_04_19 already added.
# Date 2017_04_14 already added.
# Date 2017_04_12 already added.
# Date 2017_04_11 already added.
# Date 2017_04_10 already added.
# Date 2017_04_08 already added.
# Date 2017_04_06 already added.
# Date 2017_04_05 already added.
# Date 2017_04_04 already added.
# Date 2017_04_03 already added.
# Date 2017_04_02 already added.
# Date 2017_04_01 already added.
# Date 2017_03_31 already added.
# Date 2017_03_29 already added.
# Date 2017_03_28 already added.
# Date 2017_03_27 already added.
# Date 2017_03_26 already added.
# Date 2017_03_25 already added.
# Date 2017_03_24 already added.
# Date 2017_03_23 already added.
# Date 2017_03_22 already added.
# Date 2017_03_21 already added.
# Date 2017_03_20 already added.
# Date 2017_03_18 already added.
# Date 2017_03_17 already added.
# Date 2017_03_16 already added.
# Date 2017_03_13 already added.
# Date 2017_03_10 already added.
# Date 2017_03_08 already added.
# Date 2017_03_07 already added.
# Date 2017_03_06 already added.
# Date 2017_03_05 already added.
# Date 2017_03_04 already added.
# Date 2017_03_02 already added.
# Date 2017_03_01 already added.
# Date 2017_02_28 already added.
# Date 2017_02_27 already added.
# Date 2017_02_26 already added.
# Date 2017_02_24 already added.
# Date 2017_02_23 already added.
# Date 2017_02_22 already added.
# Date 2017_02_21 already added.
# Date 2017_02_20 already added.
# Date 2017_02_17 already added.
# Date 2017_02_16 already added.
# Date 2017_02_15 already added.
# Date 2017_02_14 already added.
# Date 2017_02_13 already added.
# Date 2017_02_10 already added.
# Date 2017_02_09 already added.
# Date 2017_02_08 already added.
# Date 2017_02_07 already added.
# Date 2017_02_06 already added.
# Date 2017_02_05 already added.
# Date 2017_02_03 already added.
# Date 2017_01_31 already added.
# Date 2017_01_30 already added.
# Date 2017_01_28 already added.
# Date 2017_01_27 already added.
# Date 2017_01_25 already added.
# Date 2017_01_21 already added.
# Date 2017_01_20 already added.
# Date 2017_01_19 already added.
# Date 2017_01_17 already added.
# Date 2017_01_16 already added.
# Date 2017_01_13 already added.
# Date 2017_01_12 already added.
# Date 2017_01_11 already added.
# Date 2017_01_10 already added.
# Date 2017_01_09 already added.
# Date 2017_01_06 already added.
# Date 2017_01_01 already added.
# Date 2016_12_30 already added.
# Date 2016_12_28 already added.
# Date 2016_12_27 already added.
# Date 2016_12_17 already added.
# Date 2016_12_07 already added.
# Date 2016_12_05 already added.
# Date 2016_12_04 already added.
# Date 2016_12_02 already added.
# Date 2016_12_01 already added.
# Date 2016_11_30 already added.
# Date 2016_11_29 already added.
# Date 2016_11_28 already added.
# Date 2016_11_27 already added.
# Date 2016_11_26 already added.
# Date 2016_11_25 already added.
# Date 2016_11_24 already added.
# Date 2016_11_23 already added.
# Date 2016_11_22 already added.
# Date 2016_11_21 already added.
# Date 2016_11_20 already added.
# Date 2016_11_19 already added.
# Date 2016_11_18 already added.
# Date 2016_11_16 already added.
# Date 2016_11_15 already added.
# Date 2016_11_14 already added.
# Date 2016_11_12 already added.
# Date 2016_11_10 already added.
# Date 2016_11_09 already added.
# Date 2016_11_08 already added.
# Date 2016_11_07 already added.
# Date 2016_11_06 already added.
# Date 2016_11_05 already added.
# Date 2016_11_04 already added.
# Date 2016_11_03 already added.
# Date 2016_11_02 already added.
# Date 2016_10_31 already added.
# Date 2016_10_30 already added.
# Date 2016_10_29 already added.
# Date 2016_10_28 already added.
# Date 2016_10_27 already added.
# Date 2016_10_26 already added.
# Date 2016_10_25 already added.
# Date 2016_10_24 already added.
# Date 2016_10_22 already added.
# Date 2016_10_19 already added.
# Date 2016_10_18 already added.
# Date 2016_10_17 already added.
# Date 2016_10_16 already added.
# Date 2016_10_15 already added.
# Date 2016_10_14 already added.
# Date 2016_10_13 already added.
# Date 2016_10_12 already added.
# Date 2016_10_11 already added.
# Date 2016_10_10 already added.
# Date 2016_10_09 already added.
# Date 2016_10_06 already added.
# Date 2016_10_05 already added.
# Date 2016_10_04 already added.
# Date 2016_10_03 already added.
# Date 2016_10_01 already added.
# Date 2016_09_30 already added.
# Date 2016_09_29 already added.
# Date 2016_09_27 already added.
# Date 2016_09_25 already added.
# Date 2016_09_24 already added.
# Date 2016_09_23 already added.
# Date 2016_09_22 already added.
# Date 2016_09_21 already added.
# Date 2016_09_20 already added.
# Date 2016_09_19 already added.
# Date 2016_09_18 already added.
# Date 2016_09_17 already added.
# Date 2016_09_16 already added.
# Date 2016_09_15 already added.
# Date 2016_09_14 already added.
# Date 2016_09_13 already added.
# Date 2016_09_12 already added.
# Date 2016_09_11 already added.
# Date 2016_09_10 already added.
# Date 2016_09_09 already added.
# Date 2016_09_08 already added.
# Date 2016_09_07 already added.
# Date 2016_09_05 already added.
# Date 2016_09_04 already added.
# Date 2016_09_03 already added.
# Date 2016_09_02 already added.
# Date 2016_09_01 already added.
# Date 2016_08_31 already added.
# Date 2016_08_30 already added.
# Date 2016_08_29 already added.
# Date 2016_08_28 already added.
# Date 2016_08_27 already added.
# Date 2016_08_26 already added.
# Date 2016_08_25 already added.
# Date 2016_08_24 already added.
# Date 2016_08_23 already added.
# Date 2016_08_22 already added.
# Date 2016_08_21 already added.
# Date 2016_08_20 already added.
# Date 2016_08_19 already added.
# Date 2016_08_18 already added.
# Date 2016_08_17 already added.
# Date 2016_08_15 already added.
# Date 2016_08_14 already added.
# Date 2016_08_12 already added.
# Date 2016_08_11 already added.
# Date 2016_08_10 already added.
# Date 2016_08_09 already added.
# Date 2016_08_08 already added.
# Date 2016_08_07 already added.
# Date 2016_08_03 already added.
# Date 2016_07_30 already added.
# Date 2016_07_28 already added.
# Date 2016_07_27 already added.
# Date 2016_07_26 already added.
# Date 2016_07_25 already added.
# Date 2016_07_22 already added.
# Date 2016_07_21 already added.
# Date 2016_07_20 already added.
# Date 2016_07_19 already added.
# Date 2016_07_17 already added.
# Date 2016_07_13 already added.
# Date 2016_07_12 already added.
# Date 2016_07_11 already added.
# Date 2016_07_10 already added.
# Date 2016_07_07 already added.
# Date 2016_07_06 already added.
# Date 2016_07_05 already added.
# Date 2016_07_04 already added.
# Date 2016_07_03 already added.
# Date 2016_07_01 already added.
# Date 2016_06_30 already added.
# Date 2016_06_29 already added.
# Date 2016_06_28 already added.
# Date 2016_06_27 already added.
# Date 2016_06_26 already added.
# Date 2016_06_24 already added.
# Date 2016_06_23 already added.
# Date 2016_06_22 already added.
# Date 2016_06_21 already added.
# Date 2016_06_20 already added.
# Date 2016_06_19 already added.
# Date 2016_06_18 already added.
# Date 2016_06_16 already added.
# Date 2016_06_15 already added.
# Date 2016_06_14 already added.
# Date 2016_06_13 already added.
# Date 2016_06_12 already added.
# Date 2016_06_11 already added.
# Date 2016_06_10 already added.
# Date 2016_06_08 already added.
# Date 2016_06_07 already added.
# Date 2016_06_06 already added.
# Date 2016_06_05 already added.
# Date 2016_06_02 already added.
# Date 2016_06_01 already added.
# Date 2016_05_28 already added.
# Date 2016_05_27 already added.
# Date 2016_05_26 already added.
# Date 2016_05_25 already added.
# Date 2016_05_24 already added.
# Date 2016_05_23 already added.
# Date 2016_05_17 already added.
# Date 2016_05_16 already added.
# Date 2016_05_14 already added.
# Date 2016_05_13 already added.
# Date 2016_05_12 already added.
# Date 2016_05_11 already added.
# Date 2016_05_10 already added.
# Date 2016_05_09 already added.
# Date 2016_05_08 already added.
# Date 2016_05_07 already added.
# Date 2016_05_04 already added.
# Date 2016_05_03 already added.
# Date 2016_04_30 already added.
# Date 2016_04_29 already added.
# Date 2016_04_27 already added.
# Date 2016_04_26 already added.
# Date 2016_04_25 already added.
# Date 2016_04_23 already added.
# Date 2016_04_22 already added.
# Date 2016_04_21 already added.
# Date 2016_04_20 already added.
# Date 2016_04_19 already added.
# Date 2016_04_18 already added.
# Date 2016_04_17 already added.
# Date 2016_04_14 already added.
# Date 2016_04_13 already added.
# Date 2016_04_12 already added.
# Date 2016_04_11 already added.
# Date 2016_04_08 already added.
# Date 2016_04_07 already added.
# Date 2016_04_06 already added.
# Date 2016_04_05 already added.
# Date 2016_04_04 already added.
# Date 2016_04_03 already added.
# Date 2016_04_02 already added.
# Date 2016_04_01 already added.
# Date 2016_03_31 already added.
# Date 2016_03_30 already added.
# Date 2016_03_29 already added.
# Date 2016_03_28 already added.
# Date 2016_03_27 already added.
# Date 2016_03_26 already added.
# Date 2016_03_25 already added.
# Date 2016_03_24 already added.
# Date 2016_03_23 already added.
# Date 2016_03_22 already added.
# Date 2016_03_21 already added.
# Date 2016_03_20 already added.
# Date 2016_03_19 already added.
# Date 2016_03_18 already added.
# Date 2016_03_17 already added.
# Date 2016_03_16 already added.
# Date 2016_03_15 already added.
# Date 2016_03_14 already added.
# Date 2016_03_13 already added.
# Date 2016_03_12 already added.
# Date 2016_03_11 already added.
# Date 2016_03_10 already added.
# Date 2016_03_09 already added.
# Date 2016_03_08 already added.
# Date 2016_03_06 already added.
# Date 2016_03_05 already added.
# Date 2016_03_04 already added.
# Date 2016_03_03 already added.
# Date 2016_03_02 already added.
# Date 2016_03_01 already added.
# Date 2016_02_29 already added.
# Date 2016_02_28 already added.
# Date 2016_02_26 already added.
# Date 2016_02_25 already added.
# Date 2016_02_24 already added.
# Date 2016_02_23 already added.
# Date 2016_02_22 already added.
# Date 2016_02_21 already added.
# Date 2016_02_19 already added.
# Date 2016_02_18 already added.
# Date 2016_02_17 already added.
# Date 2016_02_16 already added.
# Date 2016_02_13 already added.
# Date 2016_02_11 already added.
# Date 2016_02_10 already added.
# Date 2016_02_09 already added.
# Date 2016_02_08 already added.
# Date 2016_02_06 already added.
# Date 2016_02_05 already added.
# Date 2016_02_04 already added.
# Date 2016_02_03 already added.
# Date 2016_02_01 already added.
# Date 2016_01_31 already added.
# Date 2016_01_29 already added.
# Date 2016_01_28 already added.
# Date 2016_01_27 already added.
# Date 2016_01_26 already added.
# Date 2016_01_25 already added.
# Date 2016_01_22 already added.
# Date 2016_01_21 already added.
# Date 2016_01_20 already added.
# Date 2016_01_19 already added.
# Date 2016_01_18 already added.
# Date 2016_01_17 already added.
# Date 2016_01_16 already added.
# Date 2016_01_15 already added.
# Date 2016_01_14 already added.
# Date 2016_01_13 already added.
# Date 2016_01_11 already added.
# Date 2016_01_09 already added.
# Date 2016_01_08 already added.
# Date 2016_01_07 already added.
# Date 2016_01_06 already added.
# Date 2016_01_04 already added.
# Date 2015_12_31 already added.
# Date 2015_12_30 already added.
# Date 2015_12_29 already added.
# Date 2015_12_28 already added.
# Date 2015_12_27 already added.
# Date 2015_12_24 already added.
# Date 2015_12_23 already added.
# Date 2015_12_22 already added.
# Date 2015_12_21 already added.
# Date 2015_12_19 already added.
# Date 2015_12_18 already added.
# Date 2015_12_17 already added.
# Date 2015_12_16 already added.
# Date 2015_12_15 already added.
# Date 2015_12_14 already added.
# Date 2015_12_12 already added.
# Date 2015_12_11 already added.
# Date 2015_12_09 already added.
# Date 2015_12_08 already added.
# Date 2015_12_07 already added.
# Date 2015_12_06 already added.
# Date 2015_12_05 already added.
# Date 2015_12_04 already added.
# Date 2015_12_03 already added.
# Date 2015_12_02 already added.
# Date 2015_12_01 already added.
# Date 2015_11_30 already added.
# Date 2015_11_29 already added.
# Date 2015_11_28 already added.
# Date 2015_11_25 already added.
# Date 2015_11_24 already added.
# Date 2015_11_23 already added.
# Date 2015_11_20 already added.
# Date 2015_11_19 already added.
# Date 2015_11_18 already added.
# Date 2015_11_17 already added.
# Date 2015_11_16 already added.
# Date 2015_11_15 already added.
# Date 2015_11_13 already added.
# Date 2015_11_12 already added.
# Date 2015_11_11 already added.
# Date 2015_11_10 already added.
# Date 2015_11_09 already added.
# Date 2015_11_08 already added.
# Date 2015_11_07 already added.
# Date 2015_11_06 already added.
# Date 2015_11_04 already added.
# Date 2015_11_03 already added.
# Date 2015_11_02 already added.
# Date 2015_11_01 already added.
# Date 2015_10_31 already added.
# Date 2015_10_30 already added.
# Date 2015_10_29 already added.
# Date 2015_10_28 already added.
# Date 2015_10_27 already added.
# Date 2015_10_26 already added.
# Date 2015_10_25 already added.
# Date 2015_10_24 already added.
# Date 2015_10_23 already added.
# Date 2015_10_22 already added.
# Date 2015_10_21 already added.
# Date 2015_10_20 already added.
# Date 2015_10_19 already added.
# Date 2015_10_18 already added.
# Date 2015_10_17 already added.
# Date 2015_10_15 already added.
# Date 2015_10_14 already added.
# Date 2015_10_13 already added.
# Date 2015_10_12 already added.
# Date 2015_10_11 already added.
# Date 2015_10_10 already added.
# Date 2015_10_09 already added.
# Date 2015_10_08 already added.
# Date 2015_10_07 already added.
# Date 2015_10_06 already added.
# Date 2015_10_05 already added.
# Date 2015_10_04 already added.
# Date 2015_10_02 already added.
# Date 2015_10_01 already added.
# Date 2015_09_30 already added.
# Date 2015_09_29 already added.
# Date 2015_09_28 already added.
# Date 2015_09_27 already added.
# Date 2015_09_26 already added.
# Date 2015_09_25 already added.
# Date 2015_09_24 already added.
# Date 2015_09_23 already added.
# Date 2015_09_22 already added.
# Date 2015_09_21 already added.
# Date 2015_09_20 already added.
# Date 2015_09_19 already added.
# Date 2015_09_18 already added.
# Date 2015_09_17 already added.
# Date 2015_09_16 already added.
# Date 2015_09_15 already added.
# Date 2015_09_14 already added.
# Date 2015_09_13 already added.
# Date 2015_09_12 already added.
# Date 2015_09_10 already added.
# Date 2015_09_09 already added.
# Date 2015_09_08 already added.
# Date 2015_09_06 already added.
# Date 2015_09_04 already added.
# Date 2015_09_03 already added.
# Date 2015_09_02 already added.
# Date 2015_09_01 already added.
# Date 2015_08_30 already added.
# Date 2015_08_29 already added.
# Date 2015_08_28 already added.
# Date 2015_08_27 already added.
# Date 2015_08_26 already added.
# Date 2015_08_25 already added.
# Date 2015_08_24 already added.
# Date 2015_08_23 already added.
# Date 2015_08_22 already added.
# Date 2015_08_21 already added.
# Date 2015_08_20 already added.
# Date 2015_08_19 already added.
# Date 2015_08_18 already added.
# Date 2015_08_17 already added.
# Date 2015_08_16 already added.
# Date 2015_08_15 already added.
# Date 2015_08_14 already added.
# Date 2015_08_13 already added.
# Date 2015_08_12 already added.
# Date 2015_08_11 already added.
# Date 2015_08_10 already added.
# Date 2015_08_08 already added.
# Date 2015_08_07 already added.
# Date 2015_08_06 already added.
# Date 2015_08_05 already added.
# Date 2015_08_04 already added.
# Date 2015_08_02 already added.
# Date 2015_07_31 already added.
# Date 2015_07_30 already added.
# Date 2015_07_29 already added.
# Date 2015_07_28 already added.
# Date 2015_07_25 already added.
# Date 2015_07_24 already added.
# Date 2015_07_23 already added.
# Date 2015_07_22 already added.
# Date 2015_07_21 already added.
# Date 2015_07_20 already added.
# Date 2015_07_19 already added.
# Date 2015_07_18 already added.
# Date 2015_07_17 already added.
# Date 2015_07_16 already added.
# Date 2015_07_14 already added.
# Date 2015_07_13 already added.
# Date 2015_07_12 already added.
# Date 2015_07_10 already added.
# Date 2015_07_09 already added.
# Date 2015_07_08 already added.
# Date 2015_07_07 already added.
# Date 2015_07_06 already added.
# Date 2015_07_05 already added.
# Date 2015_07_03 already added.
# Date 2015_07_02 already added.
# Date 2015_07_01 already added.
# Date 2015_06_30 already added.
# Date 2015_06_29 already added.
# Date 2015_06_28 already added.
# Date 2015_06_26 already added.
# Date 2015_06_25 already added.
# Date 2015_06_24 already added.
# Date 2015_06_23 already added.
# Date 2015_06_22 already added.
# Date 2015_06_20 already added.
# Date 2015_06_19 already added.
# Date 2015_06_18 already added.
# Date 2015_06_17 already added.
# Date 2015_06_16 already added.
# Date 2015_06_12 already added.
# Date 2015_06_11 already added.
# Date 2015_06_10 already added.
# Date 2015_06_09 already added.
# Date 2015_06_05 already added.
# Date 2015_06_04 already added.
# Date 2015_06_03 already added.
# Date 2015_06_02 already added.
# Date 2015_05_31 already added.
# Date 2015_05_29 already added.
# Date 2015_05_28 already added.
# Date 2015_05_27 already added.
# Date 2015_05_26 already added.
# Date 2015_05_25 already added.
# Date 2015_05_23 already added.
# Date 2015_05_22 already added.
# Date 2015_05_21 already added.
# Date 2015_05_20 already added.
# Date 2015_05_19 already added.
# Date 2015_05_18 already added.
# Date 2015_05_17 already added.
# Date 2015_05_16 already added.
# Date 2015_05_15 already added.
# Date 2015_05_14 already added.
# Date 2015_05_13 already added.
# Date 2015_05_11 already added.
# Date 2015_05_09 already added.
# Date 2015_05_08 already added.
# Date 2015_05_07 already added.
# Date 2015_05_05 already added.
# Date 2015_05_04 already added.
# Date 2015_05_01 already added.
# Date 2015_04_30 already added.
# Date 2015_04_29 already added.
# Date 2015_04_27 already added.
# Date 2015_04_26 already added.
# Date 2015_04_25 already added.
# Date 2015_04_24 already added.
# Date 2015_04_23 already added.
# Date 2015_04_22 already added.
# Date 2015_04_21 already added.
# Date 2015_04_20 already added.
# Date 2015_04_19 already added.
# Date 2015_04_18 already added.
# Date 2015_04_17 already added.
# Date 2015_04_16 already added.
# Date 2015_04_15 already added.
# Date 2015_04_14 already added.
# Date 2015_04_13 already added.
# Date 2015_04_12 already added.
# Date 2015_04_10 already added.
# Date 2015_04_09 already added.
# Date 2015_04_08 already added.
# Date 2015_04_07 already added.
# Date 2015_04_06 already added.
# Date 2015_04_04 already added.
# Date 2015_04_03 already added.
# Date 2015_04_02 already added.
# Date 2015_04_01 already added.
# Date 2015_03_31 already added.
# Date 2015_03_30 already added.
# Date 2015_03_29 already added.
# Date 2015_03_28 already added.
# Date 2015_03_27 already added.
# Date 2015_03_26 already added.
# Date 2015_03_25 already added.
# Date 2015_03_24 already added.
# Date 2015_03_23 already added.
# Date 2015_03_22 already added.
# Date 2015_03_21 already added.
# Date 2015_03_20 already added.
# Date 2015_03_19 already added.
# Date 2015_03_18 already added.
# Date 2015_03_17 already added.
# Date 2015_03_16 already added.
# Date 2015_03_15 already added.
# Date 2015_03_12 already added.
# Date 2015_03_11 already added.
# Date 2015_03_10 already added.
# Date 2015_03_07 already added.
# Date 2015_03_06 already added.
# Date 2015_03_05 already added.
# Date 2015_03_04 already added.
# Date 2015_03_03 already added.
# Date 2015_03_02 already added.
# Date 2015_03_01 already added.
# Date 2015_02_27 already added.
# Date 2015_02_25 already added.
# Date 2015_02_24 already added.
# Date 2015_02_23 already added.
# Date 2015_02_22 already added.
# Date 2015_02_21 already added.
# Date 2015_02_20 already added.
# Date 2015_02_19 already added.
# Date 2015_02_17 already added.
# Date 2015_02_16 already added.
# Date 2015_02_15 already added.
# Date 2015_02_14 already added.
# Date 2015_02_13 already added.
# Date 2015_02_12 already added.
# Date 2015_02_11 already added.
# Date 2015_02_10 already added.
# Date 2015_02_09 already added.
# Date 2015_02_08 already added.
# Date 2015_02_06 already added.
# Date 2015_02_05 already added.
# Date 2015_02_04 already added.
# Date 2015_02_03 already added.
# Date 2015_02_02 already added.
# ...
# Date 2011_07_05 already added.
# Date 2011_07_02 already added.
# Date 2011_07_01 already added.
# Date 2011_06_30 already added.
# Date 2011_06_29 already added.
# Date 2011_06_28 already added.
# Date 2011_06_27 already added.
# Date 2011_06_24 already added.
# Date 2011_06_23 already added.
# Date 2011_06_22 already added.
# Date 2011_06_21 already added.
# Date 2011_06_20 already added.
# Date 2011_06_19 already added.
# Date 2011_06_17 already added.
# Date 2011_06_16 already added.
# Date 2011_06_14 already added.
# Date 2011_06_13 already added.
# Date 2011_06_12 already added.
# Date 2011_06_10 already added.
# Date 2011_06_08 already added.
# Date 2011_06_07 already added.
# Date 2011_06_06 already added.
# Date 2011_06_04 already added.
# Date 2011_06_03 already added.
# Date 2011_06_02 already added.
# Date 2011_05_31 already added.
# Date 2011_05_30 already added.
# Date 2011_05_26 already added.
# Date 2011_05_25 already added.
# Date 2011_05_24 already added.
# Date 2011_05_22 already added.
# Date 2011_05_20 already added.
# Date 2011_05_19 already added.
# Date 2011_05_17 already added.
# Date 2011_05_16 already added.
# Date 2011_05_13 already added.
# Date 2011_05_11 already added.
# Date 2011_05_09 already added.
# Date 2011_05_07 already added.
# Date 2011_05_06 already added.
# Date 2011_05_03 already added.
# Date 2011_05_02 already added.
# Date 2011_05_01 already added.
# Date 2011_04_30 already added.
# Date 2011_04_29 already added.
# Date 2011_04_28 already added.
# Date 2011_04_27 already added.
# Date 2011_04_26 already added.
# Date 2011_04_25 already added.
# Date 2011_04_24 already added.
# Date 2011_04_23 already added.
# Date 2011_04_22 already added.
# Date 2011_04_19 already added.
# Date 2011_04_15 already added.
# Date 2011_04_14 already added.
# Date 2011_04_13 already added.
# Date 2011_04_12 already added.
# Date 2011_04_11 already added.
# Date 2011_04_10 already added.
# Date 2011_04_09 already added.
# Date 2011_04_08 already added.
# Date 2011_04_07 already added.
# Date 2011_04_06 already added.
# Date 2011_04_05 already added.
# Date 2011_04_04 already added.
# Date 2011_04_03 already added.
# Date 2011_04_02 already added.
# Date 2011_04_01 already added.
# Date 2011_03_31 already added.
# Date 2011_03_30 already added.
# Date 2011_03_29 already added.
# Date 2011_03_28 already added.
# Date 2011_03_27 already added.
# Date 2011_03_26 already added.
# Date 2011_03_25 already added.
# Date 2011_03_24 already added.
# Date 2011_03_23 already added.
# Date 2011_03_22 already added.
# Date 2011_03_21 already added.
# Date 2011_03_20 already added.
# Date 2011_03_19 already added.
# Date 2011_03_18 already added.
# Date 2011_03_17 already added.
# Date 2011_03_16 already added.
# Date 2011_03_14 already added.
# Date 2011_03_11 already added.
# Date 2011_03_09 already added.
# Date 2011_03_08 already added.
# Date 2011_03_07 already added.
# Date 2011_03_05 already added.
# Date 2011_03_04 already added.
# Date 2011_03_03 already added.
# Date 2011_03_02 already added.
# Date 2011_03_01 already added.
# Date 2011_02_28 already added.
# Date 2011_02_27 already added.
# Date 2011_02_26 already added.
# Date 2011_02_25 already added.
# Date 2011_02_24 already added.
# Date 2011_02_23 already added.
# Date 2011_02_21 already added.
# Date 2011_02_20 already added.
# Date 2011_02_19 already added.
# Date 2011_02_18 already added.
# Date 2011_02_17 already added.
# Date 2011_02_16 already added.
# Date 2011_02_15 already added.
# Date 2011_02_14 already added.
# Date 2011_02_13 already added.
# Date 2011_02_12 already added.
# Date 2011_02_11 already added.
# Date 2011_02_10 already added.
# Date 2011_02_09 already added.
# Date 2011_02_06 already added.
# Date 2011_02_05 already added.
# Date 2011_02_03 already added.
# Date 2011_02_02 already added.
# Date 2011_02_01 already added.
# Date 2011_01_31 already added.
# Date 2011_01_28 already added.
# Date 2011_01_27 already added.
# Date 2011_01_26 already added.
# Date 2011_01_25 already added.
# Date 2011_01_23 already added.
# Date 2011_01_22 already added.
# Date 2011_01_21 already added.
# Date 2011_01_19 already added.
# Date 2011_01_17 already added.
# Date 2011_01_16 already added.
# Date 2011_01_13 already added.
# Date 2011_01_12 already added.
# Date 2011_01_11 already added.
# Date 2011_01_10 already added.
# Date 2011_01_09 already added.
# Date 2011_01_08 already added.
# Date 2011_01_06 already added.
# Date 2011_01_04 already added.
# Date 2011_01_02 already added.
# Date 2010_12_31 already added.
# Date 2010_12_30 already added.
# Date 2010_12_29 already added.
# Date 2010_12_26 already added.
# Date 2010_12_23 already added.
# Date 2010_12_22 already added.
# Date 2010_12_21 already added.
# Date 2010_12_20 already added.
# Date 2010_12_18 already added.
# Date 2010_12_17 already added.
# Date 2010_12_15 already added.
# Date 2010_12_14 already added.
# Date 2010_12_13 already added.
# Date 2010_12_10 already added.
# Date 2010_12_09 already added.
# Date 2010_12_08 already added.
# Date 2010_12_07 already added.
# Date 2010_12_05 already added.
# Date 2010_12_02 already added.
# Date 2010_12_01 already added.
# Date 2010_11_29 already added.
# Date 2010_11_28 already added.
# Date 2010_11_26 already added.
# Date 2010_11_25 already added.
# Date 2010_11_23 already added.
# Date 2010_11_22 already added.
# Date 2010_11_20 already added.
# Date 2010_11_19 already added.
# Date 2010_11_18 already added.
# Date 2010_11_17 already added.
# Date 2010_11_16 already added.
# Date 2010_11_15 already added.
# Date 2010_11_14 already added.
# Date 2010_11_13 already added.
# Date 2010_11_12 already added.
# Date 2010_11_11 already added.
# Date 2010_11_10 already added.
# Date 2010_11_09 already added.
# Date 2010_11_08 already added.
# Date 2010_11_07 already added.
# Date 2010_11_05 already added.
# Date 2010_11_04 already added.
# Date 2010_11_03 already added.
# Date 2010_11_02 already added.
# Date 2010_11_01 already added.
# Date 2010_10_31 already added.
# Date 2010_10_29 already added.
# Date 2010_10_28 already added.
# Date 2010_10_27 already added.
# Date 2010_10_26 already added.
# Date 2010_10_25 already added.
# Date 2010_10_24 already added.
# Date 2010_10_23 already added.
# Date 2010_10_22 already added.
# Date 2010_10_21 already added.
# Date 2010_10_20 already added.
# Date 2010_10_19 already added.
# Date 2010_10_17 already added.
# Date 2010_10_16 already added.
# Date 2010_10_13 already added.
# Date 2010_10_12 already added.
# Date 2010_10_11 already added.
# Date 2010_10_10 already added.
# Date 2010_10_08 already added.
# Date 2010_10_07 already added.
# Date 2010_10_05 already added.
# Date 2010_10_04 already added.
# Date 2010_10_03 already added.
# Date 2010_10_02 already added.
# Date 2010_10_01 already added.
# Date 2010_09_29 already added.
# Date 2010_09_28 already added.
# Date 2010_09_27 already added.
# Date 2010_09_24 already added.
# Date 2010_09_23 already added.
# Date 2010_09_22 already added.
# Date 2010_09_21 already added.
# Date 2010_09_20 already added.
# Date 2010_09_18 already added.
# Date 2010_09_17 already added.
# Date 2010_09_16 already added.
# Date 2010_09_15 already added.
# Date 2010_09_14 already added.
# Date 2010_09_13 already added.
# Date 2010_09_11 already added.
# Date 2010_09_10 already added.
# Date 2010_09_09 already added.
# Date 2010_09_08 already added.
# Date 2010_09_07 already added.
# Date 2010_09_06 already added.
# Date 2010_09_04 already added.
# Date 2010_09_03 already added.
# Date 2010_09_02 already added.
# Date 2010_09_01 already added.
# Date 2010_08_30 already added.
# Date 2010_08_29 already added.
# Date 2010_08_28 already added.
# Date 2010_08_26 already added.
# Date 2010_08_25 already added.
# Date 2010_08_24 already added.
# Date 2010_08_23 already added.
# Date 2010_08_21 already added.
# Date 2010_08_20 already added.
# Date 2010_08_18 already added.
# Date 2010_08_16 already added.
# Date 2010_08_15 already added.
# Date 2010_08_14 already added.
# Date 2010_08_12 already added.
# Date 2010_08_11 already added.
# Date 2010_08_09 already added.
# Date 2010_08_07 already added.
# Date 2010_08_06 already added.
# Date 2010_08_04 already added.
# Date 2010_08_03 already added.
# Date 2010_08_02 already added.
# Date 2010_08_01 already added.
# Date 2010_07_30 already added.
# Date 2010_07_29 already added.
# Date 2010_07_27 already added.
# Date 2010_07_23 already added.
# Date 2010_07_22 already added.
# Date 2010_07_21 already added.
# Date 2010_07_19 already added.
# Date 2010_07_16 already added.
# Date 2010_07_15 already added.
# Date 2010_07_14 already added.
# Date 2010_07_13 already added.
# Date 2010_07_12 already added.
# Date 2010_07_11 already added.
# Date 2010_07_10 already added.
# Date 2010_07_09 already added.
# Date 2010_07_08 already added.
# Date 2010_07_07 already added.
# Date 2010_07_05 already added.
# Date 2010_07_04 already added.
# Date 2010_07_02 already added.
# Date 2010_07_01 already added.
# Date 2010_06_30 already added.
# Date 2010_06_29 already added.
# Date 2010_06_28 already added.
# Date 2010_06_24 already added.
# Date 2010_06_22 already added.
# Date 2010_06_21 already added.
# Date 2010_06_18 already added.
# Date 2010_06_17 already added.
# Date 2010_06_16 already added.
# Date 2010_06_15 already added.
# Date 2010_06_14 already added.
# Date 2010_06_13 already added.
# Date 2010_06_11 already added.
# Date 2010_06_10 already added.
# Date 2010_06_09 already added.
# Date 2010_06_08 already added.
# Date 2010_06_06 already added.
# Date 2010_06_04 already added.
# Date 2010_06_03 already added.
# Date 2010_06_02 already added.
# Date 2010_06_01 already added.
# Date 2010_05_30 already added.
# Date 2010_05_29 already added.
# Date 2010_05_27 already added.
# Date 2010_05_24 already added.
# Date 2010_05_23 already added.
# Date 2010_05_22 already added.
# Date 2010_05_20 already added.
# Date 2010_05_19 already added.
# Date 2010_05_13 already added.
# Date 2010_05_11 already added.
# Date 2010_05_10 already added.
# Date 2010_05_08 already added.
# Date 2010_05_06 already added.
# Date 2010_05_04 already added.
# Date 2010_05_03 already added.
# Date 2010_04_29 already added.
# Date 2010_04_27 already added.
# Date 2010_04_26 already added.
# Date 2010_04_25 already added.
# Date 2010_04_24 already added.
# Date 2010_04_22 already added.
# Date 2010_04_20 already added.
# Date 2010_04_18 already added.
# Date 2010_04_16 already added.
# Date 2010_04_15 already added.
# Date 2010_04_14 already added.
# Date 2010_04_12 already added.
# Date 2010_04_11 already added.
# Date 2010_04_09 already added.
# Date 2010_04_08 already added.
# Date 2010_04_07 already added.
# Date 2010_04_06 already added.
# Date 2010_04_05 already added.
# Date 2010_04_04 already added.
# Date 2010_04_02 already added.
# Date 2010_04_01 already added.
# Date 2010_03_31 already added.
# Date 2010_03_30 already added.
# Date 2010_03_29 already added.
# Date 2010_03_25 already added.
# Date 2010_03_24 already added.
# Date 2010_03_23 already added.
# Date 2010_03_22 already added.
# Date 2010_03_21 already added.
# Date 2010_03_20 already added.
# Date 2010_03_19 already added.
# Date 2010_03_18 already added.
# Date 2010_03_15 already added.
# Date 2010_03_08 already added.
# Date 2010_03_06 already added.
# Date 2010_03_05 already added.
# Date 2010_03_04 already added.
# Date 2010_03_03 already added.
# Date 2010_03_02 already added.
# Date 2010_03_01 already added.
# Date 2010_02_28 already added.
# Date 2010_02_27 already added.
# Date 2010_02_25 already added.
# Date 2010_02_24 already added.
# Date 2010_02_23 already added.
# Date 2010_02_22 already added.
# Date 2010_02_21 already added.
# Date 2010_02_20 already added.
# Date 2010_02_19 already added.
# Date 2010_02_18 already added.
# Date 2010_02_17 already added.
# Date 2010_02_16 already added.
# Date 2010_02_12 already added.
# Date 2010_02_11 already added.
# Date 2010_02_10 already added.
# Date 2010_02_08 already added.
# Date 2010_02_06 already added.
# Date 2010_02_05 already added.
# Date 2010_02_04 already added.
# Date 2010_02_03 already added.
# Date 2010_02_01 already added.
# Date 2010_01_30 already added.
# Date 2010_01_29 already added.
# Date 2010_01_28 already added.
# Date 2010_01_26 already added.
# Date 2010_01_24 already added.
# Date 2010_01_19 already added.
# Date 2010_01_15 already added.
# Date 2010_01_14 already added.
# Date 2010_01_13 already added.
# Date 2010_01_12 already added.
# Date 2010_01_11 already added.
# Date 2010_01_04 already added.
# Date 2010_01_01 already added.
# Date 2009_12_31 already added.
# Date 2009_12_29 already added.
# Date 2009_12_28 already added.
# Date 2009_12_27 already added.
# Date 2009_12_26 already added.
# Date 2009_12_25 already added.
# Date 2009_12_22 already added.
# Date 2009_12_20 already added.
# Date 2009_12_19 already added.
# Date 2009_12_18 already added.
# Date 2009_12_16 already added.
# Date 2009_12_15 already added.
# Date 2009_12_11 already added.
# Date 2009_12_07 already added.
# Date 2009_12_06 already added.
# Date 2009_12_05 already added.
# Date 2009_12_04 already added.
# Date 2009_12_03 already added.
# Date 2009_12_02 already added.
# Date 2009_12_01 already added.
# Date 2009_11_26 already added.
# Date 2009_11_25 already added.
# Date 2009_11_24 already added.
# Date 2009_11_22 already added.
# Date 2009_11_21 already added.
# Date 2009_11_19 already added.
# Date 2009_11_18 already added.
# Date 2009_11_17 already added.
# Date 2009_11_15 already added.
# Date 2009_11_14 already added.
# Date 2009_11_13 already added.
# Date 2009_11_11 already added.
# Date 2009_11_10 already added.
# Date 2009_11_09 already added.
# Date 2009_11_08 already added.
# Date 2009_11_07 already added.
# Date 2009_11_06 already added.
# Date 2009_11_05 already added.
# Date 2009_11_04 already added.
# Date 2009_11_03 already added.
# Date 2009_11_02 already added.
# Date 2009_11_01 already added.
# Date 2009_10_31 already added.
# Date 2009_10_30 already added.
# Date 2009_10_29 already added.
# Date 2009_10_28 already added.
# Date 2009_10_25 already added.
# Date 2009_10_24 already added.
# Date 2009_10_23 already added.
# Date 2009_10_22 already added.
# Date 2009_10_20 already added.
# Date 2009_10_19 already added.
# Date 2009_10_18 already added.
# Date 2009_10_17 already added.
# Date 2009_10_16 already added.
# Date 2009_10_15 already added.
# Date 2009_10_13 already added.
# Date 2009_10_12 already added.
# Date 2009_10_11 already added.
# Date 2009_10_09 already added.
# Date 2009_10_08 already added.
# Date 2009_10_07 already added.
# Date 2009_10_06 already added.
# Date 2009_10_05 already added.
# Date 2009_10_04 already added.
# Date 2009_10_03 already added.
# Date 2009_10_02 already added.
# Date 2009_10_01 already added.
# Date 2009_09_30 already added.
# Date 2009_09_29 already added.
# Date 2009_09_27 already added.
# Date 2009_09_25 already added.
# Date 2009_09_24 already added.
# Date 2009_09_23 already added.
# Date 2009_09_22 already added.
# Date 2009_09_21 already added.
# Date 2009_09_20 already added.
# Date 2009_09_18 already added.
# Date 2009_09_17 already added.
# Date 2009_09_14 already added.
# Date 2009_09_13 already added.
# Date 2009_09_12 already added.
# Date 2009_09_11 already added.
# Date 2009_09_10 already added.
# Date 2009_09_09 already added.
# Date 2009_09_08 already added.
# Date 2009_09_06 already added.
# Date 2009_09_05 already added.
# Date 2009_09_04 already added.
# Date 2009_09_03 already added.
# Date 2009_09_02 already added.
# Date 2009_08_31 already added.
# Date 2009_08_30 already added.
# Date 2009_08_29 already added.
# Date 2009_08_28 already added.
# Date 2009_08_27 already added.
# Date 2009_08_26 already added.
# Date 2009_08_25 already added.
# Date 2009_08_24 already added.
# Date 2009_08_22 already added.
# Date 2009_08_20 already added.
# Date 2009_08_19 already added.
# Date 2009_08_18 already added.
# Date 2009_08_17 already added.
# Date 2009_08_13 already added.
# Date 2009_08_12 already added.
# Date 2009_08_11 already added.
# Date 2009_08_10 already added.
# Date 2009_08_07 already added.
# Date 2009_08_05 already added.
# Date 2009_08_04 already added.
# Date 2009_08_02 already added.
# Date 2009_08_01 already added.
# Date 2009_07_31 already added.
# Date 2009_07_29 already added.
# Date 2009_07_28 already added.
# Date 2009_07_26 already added.
# Date 2009_07_23 already added.
# Date 2009_07_22 already added.
# Date 2009_07_21 already added.
# Date 2009_07_20 already added.
# Date 2009_07_19 already added.
# Date 2009_07_18 already added.
# Date 2009_07_17 already added.
# Date 2009_07_16 already added.
# Date 2009_07_15 already added.
# Date 2009_07_14 already added.
# Date 2009_07_13 already added.
# Date 2009_07_12 already added.
# Date 2000_09_13 added.
# Date 2000_08_22 added.

# %%
# Hyperparameters to Modify
school_name = 'UCF'
time_slice = 'yearly'

from helpers.graphers import grapher
from helpers.queries import one_query

school_names = [school_name]
save_pattern = '_'.join(school_names)+'_'+'Count'
grapher(school_names=school_names,
        pipeline=[],
        query=one_query,
        y_label=f"Articles Per School Year",
        data_path="grouped_data",
        data_name=save_pattern,
        time_slice=time_slice,
        img_path=f"figures/{school_name}/{save_pattern}_{time_slice}.png")
# Out:
# grouped_data/csv/UCF_Count.csv created.
# grouped_data/pkl/yearly/UCF_Count.pkl being created.

# %%
# Hyperparameters to Modify
school_name = 'UCF'
string = "Hillel"
time_slice = 'monthly'

from helpers.graphers import grapher
from helpers.queries import count_query

school_names = [school_name]
save_pattern = '_'.join(school_names)+'_'+string.replace(' ','_')
grapher(school_names=school_names,
        pipeline=[],
        query=count_query(string),
        y_label=f"{string} Mentions Per Year",
        data_path="grouped_data",
        data_name=save_pattern,
        time_slice=time_slice,
        title=f"Mentions of {string}",
        img_path=f"figures/{school_name}/{save_pattern}_{time_slice}.png")
# Out:
# grouped_data/csv/UCF_Hillel.csv created.
# grouped_data/pkl/monthly/UCF_Hillel.pkl being created.

# %%
from helpers.graphers import grapher
from helpers.queries import one_query

import os

school_names = os.listdir('journal_data/txt')
save_pattern = '_'.join(school_names)+'_'+'Count'
grapher(school_names=school_names,
        pipeline=[],
        query=one_query,
        y_label=f"Articles Per School Year",
        data_path="grouped_data",
        data_name=save_pattern,
        time_slice='yearly')
# Out:
# grouped_data/csv/McGill_UCF_UCSD_UF_UMich_USC_York_Count.csv already exists.
# grouped_data/pkl/yearly/McGill_UCF_UCSD_UF_UMich_USC_York_Count.pkl being read.
